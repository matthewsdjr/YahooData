# %% [markdown]
# # Libreria Yfinance
# Yfinance es una biblioteca de código abierto que permite acceder a los datos financieros de Yahoo Finance. Yfinance es una forma de descargar datos de mercado de la API de Yahoo Finance.

# %%
import yfinance

# %%
print(yfinance.__version__)
# Out:
# 0.2.38

# %%
import yfinance as yf

# Obtenemos informacion del stock "Microsoft" (msft)
msft = yf.Ticker("MSFT")

msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
msft.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'MSFT',
#  'exchangeName': 'NMS',
#  'fullExchangeName': 'NasdaqGS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 511108200,
#  'regularMarketTime': 1713297602,
#  'hasPrePostMarketData': True,
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 414.58,
#  'fiftyTwoWeekHigh': 418.4,
#  'fiftyTwoWeekLow': 413.73,
#  'regularMarketDayHigh': 418.4,
#  'regularMarketDayLow': 413.73,
#  'regularMarketVolume': 16701613,
#  'chartPreviousClose': 426.28,
#  'previousClose': 413.64,
#  'scale': 3,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EDT',
#    'end': 1713274200,
#    'start': 1713254400,
#    'gmtoffset': -14400},
#   'regular': {'timezone': 'EDT',
#    'end': 1713297600,
#    'start': 1713274200,
#    'gmtoffset': -14400},
#   'post': {'timezone': 'EDT',
#    'end': 1713312000,
#    'start': 1713297600,
#    'gmtoffset': -14400}},
# ...

# %%
dataF = yf.download("EURUSD=X", start="2024-2-25", end="2024-3-25", interval="15m")
dataF
#dataF.iloc[-1:,:]
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                          Open      High       Low     Close  Adj Close  Volume
# Datetime
# 2024-02-26 00:00:00  1.082251  1.082251  1.082134  1.082134   1.082134       0
# 2024-02-26 00:15:00  1.082251  1.082251  1.081900  1.082017   1.082017       0
# 2024-02-26 00:30:00  1.082134  1.082251  1.082134  1.082134   1.082134       0
# 2024-02-26 00:45:00  1.082134  1.082251  1.082017  1.082017   1.082017       0
# 2024-02-26 01:00:00  1.081900  1.081900  1.081666  1.081783   1.081783       0
# ...                       ...       ...       ...       ...        ...     ...
# 2024-03-22 20:15:00  1.081198  1.081198  1.081081  1.081198   1.081198       0
# 2024-03-22 20:30:00  1.081198  1.081198  1.081081  1.081081   1.081081       0
# 2024-03-22 20:45:00  1.081081  1.081315  1.081081  1.081081   1.081081       0
# 2024-03-22 21:00:00  1.081432  1.081432  1.081432  1.081432   1.081432       0
# ...

# %%
aapl = yf.Ticker("AAPL")
stcokinfo = aapl.info
for line in stcokinfo.items():
    print(line)
# Out:
# ('address1', 'One Apple Park Way')
# ('city', 'Cupertino')
# ('state', 'CA')
# ('zip', '95014')
# ('country', 'United States')
# ('phone', '408 996 1010')
# ('website', 'https://www.apple.com')
# ('industry', 'Consumer Electronics')
# ('industryKey', 'consumer-electronics')
# ('industryDisp', 'Consumer Electronics')
# ('sector', 'Technology')
# ('sectorKey', 'technology')
# ('sectorDisp', 'Technology')
# ...

# %%
marketCap = stcokinfo['marketCap']
print(marketCap)
# Out:
# int

# %%
print(aapl.recommendations)
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         11   21     6     0           0
# 1    -1m         10   17    12     2           0
# 2    -2m         10   17    12     2           0
# 3    -3m         10   24     7     1           0

# %%
print(aapl.splits)
# Out:
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
print(aapl.financials)
# Out:
#                                                         2023-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                           0.147
# Normalized EBITDA                                   129188000000.0
# Net Income From Continuing Operation Net Minori...   96995000000.0
# Reconciled Depreciation                              11519000000.0
# Reconciled Cost Of Revenue                          214137000000.0
# EBITDA                                              129188000000.0
# EBIT                                                117669000000.0
# Net Interest Income                                   -183000000.0
# Interest Expense                                      3933000000.0
# Interest Income                                       3750000000.0
# Normalized Income                                    96995000000.0
# Net Income From Continuing And Discontinued Ope...   96995000000.0
# ...

# %%
print(aapl.major_holders)
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.05936
# institutionsPercentHeld          0.56683
# institutionsFloatPercentHeld     0.60260
# institutionsCount             6188.00000

# %%
print(aapl.institutional_holders)
# Out:
#   Date Reported                             Holder  pctHeld      Shares  \
# 0    2023-06-30                 Vanguard Group Inc   0.0834  1303688506
# 1    2023-06-30                     Blackrock Inc.   0.0665  1039640859
# 2    2023-06-30            Berkshire Hathaway, Inc   0.0586   915560382
# 3    2023-06-30           State Street Corporation   0.0370   578897858
# 4    2023-06-30                           FMR, LLC   0.0196   307066638
# 5    2023-06-30      Geode Capital Management, LLC   0.0186   291538165
# 6    2023-06-30      Price (T.Rowe) Associates Inc   0.0145   226650943
# 7    2023-06-30                     Morgan Stanley   0.0131   204714950
# 8    2022-12-31  Norges Bank Investment Management   0.0107   167374278
# 9    2023-06-30         Northern Trust Corporation   0.0105   164536073
#
#           Value
# 0  252876459508
# 1  201659137420
# 2  177591247296
# 3  112288817516
# 4   59561715772
# 5   56549657865
# 6   43963483413
# 7   39708558851
# 8   21746939940
# ...

# %%
data = aapl.history(start = "2020-01-01", end = "2024-01-01")
print(data)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-01-02 00:00:00-05:00   72.059681   73.120245   71.804274   73.059433
# 2020-01-03 00:00:00-05:00   72.281027   73.115365   72.122918   72.349136
# 2020-01-06 00:00:00-05:00   71.463708   72.964542   71.210729   72.925621
# 2020-01-07 00:00:00-05:00   72.935377   73.193219   72.361316   72.582672
# 2020-01-08 00:00:00-05:00   72.283454   74.054296   72.283454   73.750237
# ...                               ...         ...         ...         ...
# 2023-12-22 00:00:00-05:00  194.931260  195.160978  192.724085  193.353287
# 2023-12-26 00:00:00-05:00  193.363270  193.642911  192.584265  192.803986
# 2023-12-27 00:00:00-05:00  192.244692  193.253399  190.846467  192.903839
# 2023-12-28 00:00:00-05:00  193.892582  194.411923  192.923817  193.333298
# 2023-12-29 00:00:00-05:00  193.652887  194.152249  191.485654  192.284637
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame()
tickers = ["AAPL", "AMZN", "TSLA"]
for ticker in tickers:
    df[ticker] = yf.Ticker(ticker).history(start = "2020-01-01", end = "2021-01-01").Close

df.plot()
plt.show()
